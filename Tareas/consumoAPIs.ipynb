# %% [markdown]
# #Tarjeta Crédito

# %%
import requests
import json
import pandas as pd

url = "https://fakerapi.it/api/v1/credit_cards?_quantity=1"
respuesta = requests.get(url)
datos = respuesta.json()
texto = json.loads(respuesta.text)
tabla = texto['data']
pd.DataFrame(tabla)
# Out:
#    type            number expiration            owner
# 0  Visa  4929783378359658      06/26  Anastasia Bauch

# %% [markdown]
# # Productos

# %%
import requests
import json
import pandas as pd

url = "https://fakerapi.it/api/v1/products?_quantity=1&_taxes=12&_categories_type=uuid"
respuesta = requests.get(url)
datos = respuesta.json()
texto = json.loads(respuesta.text)
tabla = texto['data']
pd.DataFrame(tabla)
# Out:
#    id                   name  \
# 0   1  Omnis ut magnam iste.
#
#                                          description            ean  \
# 0  Et architecto deleniti odio sunt exercitatione...  9108290927821
#
#             upc                             image  \
# 0  453608368628  http://placeimg.com/640/480/tech
#
#                                               images  net_price taxes price  \
# 0  [{'title': 'Et animi voluptatem mollitia.', 'd...       1.97    12  2.21
#
#                                           categories  \
# 0  [fe8289c2-8839-380f-bb6b-670c1f083acf, 3427c3c...
#
#                                                 tags
# 0  [laudantium, eius, ut, consequatur, et, invent...

# %% [markdown]
# #Usuarios

# %%
import requests
import json
import pandas as pd

url = "https://fakerapi.it/api/v1/users?_quantity=1&_gender=male"
respuesta = requests.get(url)
datos = respuesta.json()
texto = json.loads(respuesta.text)
tabla = texto['data']
pd.DataFrame(tabla)
# Out:
#    id                                  uuid firstname lastname      username  \
# 0   1  d8edda4e-7a9c-3459-bbe4-808e029cf0c8  Reymundo    Welch  parker.alene
#
#         password             email              ip         macAddress  \
# 0  m6N9G67SWTv-n  eden73@gmail.com  40.150.210.192  10:F4:FA:BC:E4:9E
#
#               website                               image
# 0  http://leffler.biz  http://placeimg.com/640/480/people
